# %%
import json
import pandas as pd
import re
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.min_rows', 500)

# %%
def extract_predictions_gpt3(df):
    df=df.assign(sdg1=np.where(df['GPT3_response'].str.lower().str.contains("goal 1 |goal 1:|poverty"),1,0))
    df=df.assign(sdg2=np.where(df['GPT3_response'].str.lower().str.contains("goal 2|hunger"),1,0))
    df=df.assign(sdg3=np.where(df['GPT3_response'].str.lower().str.contains("goal 3|health"),1,0))
    df=df.assign(sdg4=np.where(df['GPT3_response'].str.lower().str.contains("goal 4|education"),1,0))
    df=df.assign(sdg5=np.where(df['GPT3_response'].str.lower().str.contains("goal 5|gender"),1,0))
    df=df.assign(sdg6=np.where(df['GPT3_response'].str.lower().str.contains("goal 6|clean water"),1,0))
    df=df.assign(sdg7=np.where(df['GPT3_response'].str.lower().str.contains("goal 7|clean energy"),1,0))
    df=df.assign(sdg8=np.where(df['GPT3_response'].str.lower().str.contains("goal 8|decent work"),1,0))
    df=df.assign(sdg9=np.where(df['GPT3_response'].str.lower().str.contains("goal 9|industry|innovation"),1,0))
    df=df.assign(sdg10=np.where(df['GPT3_response'].str.lower().str.contains("goal 10|inequal"),1,0))
    df=df.assign(sdg11=np.where(df['GPT3_response'].str.lower().str.contains("goal 11|sustainable cities"),1,0))
    df=df.assign(sdg12=np.where(df['GPT3_response'].str.lower().str.contains("goal 12|responsible consumption"),1,0))
    df=df.assign(sdg13=np.where(df['GPT3_response'].str.lower().str.contains("goal 13|climate"),1,0))
    df=df.assign(sdg14=np.where(df['GPT3_response'].str.lower().str.contains("goal 14|life below water"),1,0))
    df=df.assign(sdg15=np.where(df['GPT3_response'].str.lower().str.contains("goal 15|life on land"),1,0))
    df=df.assign(sdg16=np.where(df['GPT3_response'].str.lower().str.contains("goal 16|peace|justice"),1,0))
    df=df.assign(sdg17=np.where(df['GPT3_response'].str.lower().str.contains("goal 17|partnership"),1,0))
    return df

# %%
mapping_sdg={'sdg1': 'No Poverty',
 'sdg2': 'Zero Hunger',
 'sdg3': 'Good Health and Well-Being',
 'sdg4': 'Quality Education',
 'sdg5': 'Gender Equality',
 'sdg6': 'Clean Water and Sanitation',
 'sdg7': 'Affordable and Clean Energy',
 'sdg8': 'Decent Work and Economic Growth',
 'sdg9': 'Industry, Innovation and Infrastructure',
 'sdg10': 'Reduced Inequalities',
 'sdg11': 'Sustainable Cities and Communities',
 'sdg12': 'Responsible Consumption and Production',
 'sdg13': 'Climate Action',
 'sdg14': 'Life Below Water',
 'sdg15': 'Life on Land',
 'sdg16': 'Peace, Justice and Strong Institutions',
 'sdg17': 'Partnership for the Goals'
}

# %%
outputs_path="../outputs/"
data_path="../data/"

# %%
df_labels_task=pd.read_json(outputs_path+"sg_ie/positives_tasks_methods_clusters_final_f.json")
df_task_test=pd.read_json(outputs_path+"sg_ie/test_scirex_tasks_methods_clusters_final_f.json")
df_g=pd.read_csv("../sg_match/progress_singular_gpt3.csv")

# %%
test_set=pd.read_csv(outputs_path+"general/test_set_final.csv")
train_set=pd.read_csv(outputs_path+"general/train_set_final.csv")
dev_set=pd.read_csv(outputs_path+"general/dev_set_final.csv")
df_all_goals=pd.concat([dev_set,train_set,test_set])
df_all_goals=df_all_goals.loc[df_all_goals.label==1]

# %%
df_g=df_g.loc[~df_g.ID.isin(df_all_goals.ID.unique())]

# %%
df_all_goals.goal1_raw=df_all_goals.goal1_raw.fillna('')
df_all_goals.goal2_raw=df_all_goals.goal2_raw.fillna('')
df_all_goals.goal3_raw=df_all_goals.goal3_raw.fillna('')
df_all_goals=df_all_goals.assign(goal1=np.where(df_all_goals['goal1_raw'].str.lower().str.contains("education"),'Quality Education',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("poverty"),'No Poverty',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("hunger"),'Zero Hunger',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("clean_water"),'Clean Water and Sanitation',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("clean_energy"),'Affordable and Clean Energy',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("life_land"),'Life on Land',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("marine_life"),'Life Below Water',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("health"),'Good Health and Well-Being',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("climate"),'Climate Action',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("peace|privacy|disinformation_and_fake_news|deception|hate"),'Peace, Justice and Strong Institutions',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("social biases|race & identity"),'Reduced Inequalities',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("industry|innovation|research"),'Industry, Innovation and Infrastructure',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("sustainable cities|sustainable_cities"),'Sustainable Cities and Communities',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("gender"),'Gender Equality',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("decent work|decent_work_and_economy"),'Decent Work and Economic Growth',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("partnership"),'Partnership for the Goals',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("responsible_consumption_and_production"),'Responsible Consumption and Production',
                    np.where(df_all_goals['goal1_raw'].str.lower().str.contains("reduced|social_equality"),'Reduced Inequalities',''
                          )))))))))))))))))))

df_all_goals=df_all_goals.assign(goal2=np.where(df_all_goals['goal2_raw'].str.lower().str.contains("education"),'Quality Education',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("poverty"),'No Poverty',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("hunger"),'Zero Hunger',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("clean_water"),'Clean Water and Sanitation',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("clean_energy"),'Affordable and Clean Energy',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("life_land"),'Life on Land',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("marine_life"),'Life Below Water',         
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("health"),'Good Health and Well-Being',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("climate"),'Climate Action',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("peace|privacy|disinformation_and_fake_news|deception|hate"),'Peace, Justice and Strong Institutions',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("social biases|race & identity"),'Reduced Inequalities',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("industry|innovation|research"),'Industry, Innovation and Infrastructure',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("sustainable cities|sustainable_cities"),'Sustainable Cities and Communities',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("gender"),'Gender Equality',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("decent work|decent_work_and_economy"),'Decent Work and Economic Growth',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("partnership"),'Partnership for the Goals',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("responsible_consumption_and_production"),'Responsible Consumption and Production',
                    np.where(df_all_goals['goal2_raw'].str.lower().str.contains("reduced|social_equality"),'Reduced Inequalities',''
                          )))))))))))))))))))

df_all_goals=df_all_goals.assign(goal3=np.where(df_all_goals['goal3_raw'].str.lower().str.contains("education"),'Quality Education',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("poverty"),'No Poverty',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("hunger"),'Zero Hunger',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("clean_water"),'Clean Water and Sanitation',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("clean_energy"),'Affordable and Clean Energy',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("life_land"),'Life on Land',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("marine_life"),'Life Below Water',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("health"),'Good Health and Well-Being',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("climate"),'Climate Action',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("peace|privacy|disinformation_and_fake_news|deception|hate"),'Peace, Justice and Strong Institutions',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("social biases|race & identity"),'Reduced Inequalities',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("industry|innovation|research"),'Industry, Innovation and Infrastructure',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("sustainable cities|sustainable_cities"),'Sustainable Cities and Communities',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("gender"),'Gender Equality',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("decent work|decent_work_and_economy"),'Decent Work and Economic Growth',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("partnership"),'Partnership for the Goals',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("responsible_consumption_and_production"),'Responsible Consumption and Production',
                    np.where(df_all_goals['goal3_raw'].str.lower().str.contains("reduced|social_equality"),'Reduced Inequalities',''
                          )))))))))))))))))))

# %%
df_group=pd.concat([df_all_goals.loc[:,['ID','goal1']],df_all_goals.loc[:,['ID','goal2']].rename(columns={'goal2':'goal1'}),df_all_goals.loc[:,['ID','goal3']].rename(columns={'goal3':'goal1'})])

df_group=df_group.loc[df_group.goal1!='']

df_group=df_group.rename(columns={'goal1':'Goal'})

# %%
df_g=extract_predictions_gpt3(df_g)

df_g=pd.melt(df_g,id_vars=['ID'],value_vars=['sdg1', 'sdg2', 'sdg3', 'sdg4', 'sdg5',
       'sdg6', 'sdg7', 'sdg8', 'sdg9', 'sdg10', 'sdg11', 'sdg12', 'sdg13',
       'sdg14', 'sdg15', 'sdg16', 'sdg17'],var_name=['sdg'],value_name='sdg_val')

df_g=df_g.loc[df_g.sdg_val==1]

df_g['Goal']=df_g.sdg.replace(mapping_sdg)
df_g=df_g.loc[:,['ID','Goal']]

# %%
df_goals=pd.concat([df_g,df_group])

# %%
df_goals.shape
# Out:
# (8077, 2)

# %%
df_goals.drop_duplicates().shape
# Out:
# (8072, 2)

# %%
df_goals.ID.nunique()
# Out:
# 7981

# %%
df_goals=df_goals.drop_duplicates()

# %%
df_task_test=df_task_test.loc[df_task_test.ID.isin(df_all_goals.ID.unique())]

# %%
df_task_test.ID.nunique()
# Out:
# 636

# %%
df_labels_task.ID.nunique()
# Out:
# 8133

# %%
df_labels_task=pd.concat([df_labels_task,df_task_test]).reset_index(drop=True)

# %%
df_labels_task['Method']=[list([]) for _ in range(df_labels_task.shape[0])]
df_labels_task['Task']=[list() for _ in range(df_labels_task.shape[0])]

# %%
for i,d in df_labels_task.iterrows():
    tasks=[]
    for e in d['task_scirex']:
        tasks.append(e['top_word'])
    df_labels_task.at[i,'Task']=tasks
    methods=[]
    for e in d['method_scirex']:
        methods.append(e['top_word'])
    df_labels_task.at[i,'Method']=methods

# %% [markdown]
# ## aqui

# %%
df_labels_task.ID.nunique()
# Out:
# 8472

# %%
df_labels_task=df_labels_task.merge(df_goals,on=['ID'],how='left')

# %%
df_labels_task=df_labels_task.explode('Task').rename(columns={'Task':'tasks'})

# %%
df_labels_task=df_labels_task.explode('Method').rename(columns={'Method':'methods'})

# %%
df_labels_task=df_labels_task.loc[~df_labels_task.tasks.isin(['natural language processing','nlp','nlp applications'])]

# %%
df_labels_task=df_labels_task.loc[~df_labels_task.methods.isin(['natural language processing','nlp','nlp applications'])]

# %%
df_labels_task['total_methods']=df_labels_task.groupby(['ID']).methods.transform('count')

df_labels_task['weight']=1/df_labels_task.total_methods

# %%
df_labels_task=df_labels_task.dropna()

# %%
df_labels_task.weight.sum()
# Out:
# 6930.0

# %%
###df_mapping=pd.read_csv(outputs+"words_mapping.csv")
df_mapping=pd.read_csv("../../../nlp4sg_research_tracking/sg_match/clusters.psv",sep='|')

df_mapping.center=df_mapping.center.fillna(method='ffill')

df_mapping=df_mapping.loc[df_mapping.word!='Cluster name: ']

df_mapping.word=df_mapping.word.str.rstrip(' ').str.lstrip(' ')
df_mapping.center=df_mapping.center.str.rstrip(' ').str.lstrip(' ')

df_mapping_tasks=df_mapping.rename(columns={'word':'tasks','center':'center_task'})
df_mapping_methods=df_mapping.rename(columns={'word':'methods','center':'center_method'})

df_labels_task=df_labels_task.merge(df_mapping_tasks,on=['tasks'],how='left').merge(df_mapping_methods,on=['methods'],how='left')

df_labels_task=df_labels_task.assign(tasks=np.where((~df_labels_task.center_task.isna()),df_labels_task.center_task,df_labels_task.tasks))

df_labels_task=df_labels_task.assign(methods=np.where((~df_labels_task.center_method.isna()),df_labels_task.center_method,df_labels_task.methods))

# %% [markdown]
# ## restart

# %%
df_processed_group=df_labels_task.groupby(['Goal','tasks','methods']).weight.sum().reset_index()

# %% [markdown]
# ## original papers

# %%
df_labels_task.weight.sum()
# Out:
# 6958.90357142857

# %%
top_tasks=df_processed_group.groupby(['tasks']).weight.sum().reset_index().sort_values(['weight'],ascending=False).head(25).loc[:,['tasks']]

# %%
top_methods=df_processed_group.groupby(['methods']).weight.sum().reset_index().sort_values(['weight'],ascending=False).head(25).loc[:,['methods']]

# %%
df_processed_group=df_processed_group.assign(tasks=np.where(
df_processed_group.tasks.isin(top_tasks.tasks.values),df_processed_group.tasks,"Other tasks"))

# %%
df_processed_group=df_processed_group.assign(methods=np.where(
df_processed_group.methods.isin(top_methods.methods.values),df_processed_group.methods,"Other methods"))

# %%
df_processed_group=df_processed_group.sort_values(['weight'],ascending=False)

# %%
df_processed_group=df_processed_group.groupby(['Goal','tasks','methods']).weight.sum().reset_index()

# %%
df_tops=df_processed_group.copy()

# %%
valid_methods=df_tops.loc[df_tops.methods!='Other methods',['methods']].drop_duplicates()
valid_methods=valid_methods.assign(valid_method=1)

valid_tasks=df_tops.loc[df_tops.tasks!='Other tasks',['tasks']].drop_duplicates()
valid_tasks=valid_tasks.assign(valid_task=1)

df_labels_task=df_labels_task.merge(valid_methods,on=['methods'],how='left').merge(valid_tasks,on=['tasks'],how='left')

df_labels_task.shape

df_labels_task=df_labels_task.assign(valid_method=df_labels_task.valid_method.fillna(0))
df_labels_task=df_labels_task.assign(valid_task=df_labels_task.valid_task.fillna(0))

w_valid_method=df_labels_task.groupby(['ID']).valid_method.sum().reset_index()
w_valid_method=w_valid_method.loc[w_valid_method.valid_method>0]

df_labels_task_wvm=df_labels_task.loc[df_labels_task.ID.isin(w_valid_method.ID.unique())]
df_labels_task_nwvm=df_labels_task.loc[~df_labels_task.ID.isin(w_valid_method.ID.unique())]

df_labels_task_wvm=df_labels_task_wvm.loc[df_labels_task_wvm.valid_method==1]

df_labels_task=pd.concat([df_labels_task_wvm,df_labels_task_nwvm])

w_valid_task=df_labels_task.groupby(['ID']).valid_task.sum().reset_index()
w_valid_task=w_valid_task.loc[w_valid_task.valid_task>0]

df_labels_task_wvm_t=df_labels_task.loc[df_labels_task.ID.isin(w_valid_task.ID.unique())]
df_labels_task_nwvm_t=df_labels_task.loc[~df_labels_task.ID.isin(w_valid_task.ID.unique())]

df_labels_task_wvm_t=df_labels_task_wvm_t.loc[df_labels_task_wvm_t.valid_task==1]

df_labels_task=pd.concat([df_labels_task_wvm_t,df_labels_task_nwvm_t])

df_labels_task.shape

df_labels_task.loc[df_labels_task.ID=='ghosh-etal-2020-iitp']

df_labels_task['total_methods']=df_labels_task.groupby(['ID']).methods.transform('count')

df_labels_task['weight']=1/df_labels_task.total_methods

df_labels_task=df_labels_task.loc[~((df_labels_task.methods.str.contains('translation|smt|mt'))&(df_labels_task.total_methods==1))]

df_labels_task=df_labels_task.reset_index(drop=True)

df_labels_task['total_methods']=df_labels_task.groupby(['ID']).methods.transform('count')

df_labels_task['weight']=1/df_labels_task.total_methods

# %% [markdown]
# ## restart

# %%
df_processed_group=df_labels_task.groupby(['Goal','tasks','methods']).weight.sum().reset_index()

# %%
#df_processed_group=df_processed_group.loc[df_processed_group.weight>1,:]

# %% [markdown]
# ## original papers

# %%
df_labels_task.weight.sum()
# Out:
# 6829.0

# %%
top_tasks=df_processed_group.groupby(['tasks']).weight.sum().reset_index().sort_values(['weight'],ascending=False).head(25).loc[:,['tasks']]

# %%
top_methods=df_processed_group.groupby(['methods']).weight.sum().reset_index().sort_values(['weight'],ascending=False).head(25).loc[:,['methods']]

# %%
df_processed_group=df_processed_group.assign(tasks=np.where(
df_processed_group.tasks.isin(top_tasks.tasks.values),df_processed_group.tasks,"Other tasks"))

# %%
df_processed_group=df_processed_group.assign(methods=np.where(
df_processed_group.methods.isin(top_methods.methods.values),df_processed_group.methods,"Other methods"))

# %%
df_processed_group=df_processed_group.sort_values(['weight'],ascending=False)

# %%
df_processed_group=df_processed_group.groupby(['Goal','tasks','methods']).weight.sum().reset_index()

# %% [markdown]
# ## original papers

# %%
df_processed_group.weight.sum()
# Out:
# 6829.0

# %% [markdown]
# ## sankey

# %%
df_processed_group.loc[df_processed_group.methods=='natural language processing tools']
# Out:
# Empty DataFrame
# Columns: [Goal, tasks, methods, weight]
# Index: []

# %%
df_processed_group_filtered=df_processed_group.copy()

# %%
social_needs=pd.read_csv(data_path+"others/social_needs.csv")

# %%
social_needs.Goal=social_needs.Goal.replace({'No Hunger':'Zero Hunger','Industry, Innovation and Infrastrucure':'Industry, Innovation and Infrastructure'})

# %%
social_needs=social_needs.loc[:,['Goal']].reset_index().rename(columns={'index':'order'})

# %%
df_processed_group_filtered=df_processed_group_filtered.merge(social_needs,on=['Goal'],how='left')

# %%
df_processed_group_filtered=df_processed_group_filtered.sort_values('order').reset_index(drop=True)

# %% [markdown]
# ## check this!!!!

# %%
df_processed_group_filtered.weight.sum()
# Out:
# 6829.0

# %%
## sequential
df_processed_group_filtered=df_processed_group_filtered.assign(others_count=np.where(
    df_processed_group_filtered.tasks=='Other tasks',1,0))
df_processed_group_filtered=df_processed_group_filtered.assign(others_count=np.where(
    df_processed_group_filtered.methods=='Other methods',df_processed_group_filtered.others_count+1,df_processed_group_filtered.others_count))

# %%
df_processed_group_filtered=df_processed_group_filtered.loc[(df_processed_group_filtered.others_count<=1),: ].reset_index(drop=True)

# %% [markdown]
# df_processed_group_filtered=df_processed_group_filtered.loc[((df_processed_group_filtered.Goal!='Other') &
#                                (df_processed_group_filtered.tasks!='Others') &
#                                (df_processed_group_filtered.methods!='Others')),: ].reset_index(drop=True)

# %%
df_processed_group_filtered.weight.sum()
# Out:
# 3529.0

# %%
df_processed_group_filtered.weight.sum()/(df_labels_task.weight.sum())
# Out:
# 0.5167667301215405

# %%
set(df_processed_group_filtered.tasks) & set(df_processed_group_filtered.methods)
# Out:
# {'annotation', 'classification', 'machine translation', 'nlp applications'}

# %%
df_processed_group_filtered=df_processed_group_filtered.assign(methods=np.where((df_processed_group_filtered.methods.isin(['annotation']))
                                                      ,'annotations',df_processed_group_filtered.methods))

df_processed_group_filtered=df_processed_group_filtered.assign(methods=np.where((df_processed_group_filtered.methods.isin(['automatic speech recognition']))
                                                      ,'automatic speech recognition models',df_processed_group_filtered.methods))

df_processed_group_filtered=df_processed_group_filtered.assign(methods=np.where((df_processed_group_filtered.methods.isin(['classification']))
                                                      ,'classifiers',df_processed_group_filtered.methods))

df_processed_group_filtered=df_processed_group_filtered.assign(methods=np.where((df_processed_group_filtered.methods.isin(['fact checking']))
                                                      ,'fact checking models',df_processed_group_filtered.methods))

df_processed_group_filtered=df_processed_group_filtered.assign(methods=np.where((df_processed_group_filtered.methods.isin(['named entity recognition']))
                                                      ,'ner models',df_processed_group_filtered.methods))

df_processed_group_filtered=df_processed_group_filtered.assign(methods=np.where((df_processed_group_filtered.methods.isin(['nlp applications']))
                                                      ,'nlp models',df_processed_group_filtered.methods))

df_processed_group_filtered=df_processed_group_filtered.assign(methods=np.where((df_processed_group_filtered.methods.isin(['part of speech']))
                                                      ,'part of speech models',df_processed_group_filtered.methods))

df_processed_group_filtered=df_processed_group_filtered.assign(methods=np.where((df_processed_group_filtered.methods.isin(['machine translation']))
                                                      ,'machine translation system',df_processed_group_filtered.methods))

# %%
df_processed_group_filtered=df_processed_group_filtered.assign(tasks=np.where((df_processed_group_filtered.tasks.isin(['word embeddings']))
                                                      ,'embeddings',df_processed_group_filtered.tasks))

# %%
set(df_processed_group_filtered.tasks) & set(df_processed_group_filtered.methods)
# Out:
# set()

# %%
## top 30 tasks, methods, organizations represent 1.9%

# %%
names_list=list(df_processed_group_filtered.Goal.unique())
entry_type=['Goal' for i in range(df_processed_group_filtered.Goal.nunique())]

names_list.extend(list(df_processed_group_filtered.tasks.unique()))
entry_type.extend(['task' for i in range(df_processed_group_filtered.tasks.nunique())])

names_list.extend(list(df_processed_group_filtered.methods.unique()))
entry_type.extend(['method' for i in range(df_processed_group_filtered.methods.nunique())])

names=pd.DataFrame(list(zip(names_list,entry_type)),columns=['names','types']).reset_index()

names=names.rename(columns={'index':'id'})

names_goals=names.loc[names.types=='Goal'].rename(columns={'names':'Goal'})
names_tasks=names.loc[names.types=='task'].rename(columns={'names':'tasks'})
names_methods=names.loc[names.types=='method'].rename(columns={'names':'methods'})
names_goals=names_goals.rename(columns={'id':'id_goal'})
names_tasks=names_tasks.rename(columns={'id':'id_tasks'})
names_methods=names_methods.rename(columns={'id':'id_methods'})

# %%
set(names_tasks.tasks) & set(names_methods.methods)
# Out:
# set()

# %%
df_processed_group_filtered=df_processed_group_filtered.rename(columns={'weight':'value'})

# %%
df_processed_group_filtered.loc[df_processed_group_filtered.methods=='natural language processing tools'].values
# Out:
# array([], shape=(0, 6), dtype=object)

# %%
df_processed_group_filtered=df_processed_group_filtered.merge(names_goals,on=['Goal']).merge(names_tasks,on=['tasks']).merge(names_methods,on=['methods'])

# %%
df_processed_group_filtered.value.sum()
# Out:
# 3529.0

# %%
goal_tasks=df_processed_group_filtered.groupby(['Goal','id_goal','tasks','id_tasks']).value.sum().reset_index()
tasks_methods=df_processed_group_filtered.groupby(['methods','id_methods','tasks','id_tasks']).value.sum().reset_index()

# %%
goal_tasks=goal_tasks.rename(columns={'Goal':'source','id_goal':'id_source','tasks':'target','id_tasks':'id_target'})
tasks_methods=tasks_methods.rename(columns={'tasks':'source','id_tasks':'id_source','methods':'target','id_methods':'id_target'})

# %%
goal_tasks=goal_tasks.assign(link_type='goal_tasks')
tasks_methods=tasks_methods.assign(link_type='tasks_methods')

# %%
tasks_list=goal_tasks.loc[:,['target']].drop_duplicates().rename(columns={'target':'name'}).reset_index(drop=True)

goals_list=goal_tasks.loc[:,['source']].drop_duplicates().rename(columns={'source':'name'}).reset_index(drop=True)

methods_list=tasks_methods.loc[:,['target']].drop_duplicates().rename(columns={'target':'name'}).reset_index(drop=True)

# %%
df_sankey=pd.concat([goal_tasks,tasks_methods])

# %%
df_sankey=df_sankey.assign(id_source=np.where(df_sankey.source=='Other methods',9998,df_sankey.id_source))
df_sankey=df_sankey.assign(id_source=np.where(df_sankey.source=='Other tasks',9997,df_sankey.id_source))

# %%
df_sankey=df_sankey.assign(id_target=np.where(df_sankey.target=='Other methods',9998,df_sankey.id_target))
df_sankey=df_sankey.assign(id_target=np.where(df_sankey.target=='Other tasks',9997,df_sankey.id_target))

# %%
df_sankey=df_sankey.assign(id_order=np.where(df_sankey.target.isin(['No organization','Other methods','Other tasks']),
                                             9999,
                                    np.where(df_sankey.link_type=='goal_tasks',df_sankey.id_source,999)))

# %%
df_sankey=df_sankey.sort_values(['id_order','id_source','id_target'])

# %%
df_sankey.dtypes
# Out:
# source        object
# id_source      int64
# target        object
# id_target      int64
# value        float64
# link_type     object
# id_order       int64
# dtype: object

# %%
df_sankey=df_sankey.assign(value=round(df_sankey['value'],1))

df_sankey=df_sankey.assign(id_target=df_sankey.id_target.apply(str))
df_sankey=df_sankey.assign(id_source=df_sankey.id_source.apply(str))
df_sankey.rename(columns={'value':'weight'}).to_json("sankey_no_org.json",orient="records")

# %%
df_sankey.loc[df_sankey.target=='coreference resolution']
# Out:
# Empty DataFrame
# 113   Peace, Justice and Strong Institutions        15
# 99    Peace, Justice and Strong Institutions        15
# 97    Peace, Justice and Strong Institutions        15
# 119   Peace, Justice and Strong Institutions        15
# 93                 Partnership for the Goals        16
# 89                 Partnership for the Goals        16
# 91                 Partnership for the Goals        16
# 90                 Partnership for the Goals        16
# 94                 Partnership for the Goals        16
# 92                 Partnership for the Goals        16
# 360                       sentiment analysis        17
# 428                       sentiment analysis        17
# 328                       sentiment analysis        17
# 230                       sentiment analysis        17
# 206                       sentiment analysis        17
# 180                       sentiment analysis        17
# 60                        sentiment analysis        17
# 450                       sentiment analysis        17
# 403                       sentiment analysis        17
# 274                       sentiment analysis        17
# 252                       sentiment analysis        17
# 141                       sentiment analysis        17
# 121                       sentiment analysis        17
# 83                        sentiment analysis        17
# 37                        sentiment analysis        17
# 290                       sentiment analysis        17
# 312                       sentiment analysis        17
# 385                       sentiment analysis        17
# 157                       sentiment analysis        17
# 345                       sentiment analysis        17
# 94                        sentiment analysis        17
# 352                            fact checking        18
# 414                            fact checking        18
# 217                            fact checking        18
# 195                            fact checking        18
# 166                            fact checking        18
# 45                             fact checking        18
# 262                            fact checking        18
# 245                            fact checking        18
# 128                            fact checking        18
# 112                            fact checking        18
# 70                             fact checking        18
# 280                            fact checking        18
# 235                            fact checking        18
# 300                            fact checking        18
# 149                            fact checking        18
# 337                            fact checking        18
# 89                             fact checking        18
# 350                computational linguistics        19
# 410                computational linguistics        19
# 213                computational linguistics        19
# 193                computational linguistics        19
# 41                 computational linguistics        19
# 435                computational linguistics        19
# 258                computational linguistics        19
# 366                computational linguistics        19
# 126                computational linguistics        19
# 67                 computational linguistics        19
# 234                computational linguistics        19
# 297                computational linguistics        19
# 380                computational linguistics        19
# 186                computational linguistics        19
# 348                               annotation        20
# 408                               annotation        20
# 317                               annotation        20
# 211                               annotation        20
# 191                               annotation        20
# 97                                annotation        20
# 39                                annotation        20
# 433                               annotation        20
# 256                               annotation        20
# 364                               annotation        20
# 124                               annotation        20
# 107                               annotation        20
# 65                                annotation        20
# 26                                annotation        20
# ..                                       ...       ...
# 247                              hate speech        30
# 130                              hate speech        30
# 114                              hate speech        30
# 73                               hate speech        30
# 29                               hate speech        30
# 282                              hate speech        30
# 382                              hate speech        30
# 150                              hate speech        30
# 339                              hate speech        30
# 90                               hate speech        30
# 353                      fake news detection        31
# 415                      fake news detection        31
# 218                      fake news detection        31
# 167                      fake news detection        31
# 46                       fake news detection        31
# 438                      fake news detection        31
# 390                      fake news detection        31
# 246                      fake news detection        31
# 129                      fake news detection        31
# 113                      fake news detection        31
# 71                       fake news detection        31
# 281                      fake news detection        31
# 301                      fake news detection        31
# 338                      fake news detection        31
# 359                      relation extraction        32
# 427                      relation extraction        32
# 327                      relation extraction        32
# 229                      relation extraction        32
# 205                      relation extraction        32
# 179                      relation extraction        32
# 104                      relation extraction        32
# 59                       relation extraction        32
# 449                      relation extraction        32
# 402                      relation extraction        32
# 273                      relation extraction        32
# 375                      relation extraction        32
# 251                      relation extraction        32
# 140                      relation extraction        32
# 120                      relation extraction        32
# 82                       relation extraction        32
# 36                       relation extraction        32
# 289                      relation extraction        32
# 311                      relation extraction        32
# 156                      relation extraction        32
# 426                       question answering        33
# 204                       question answering        33
# 178                       question answering        33
# 58                        question answering        33
# 401                       question answering        33
# 272                       question answering        33
# 139                       question answering        33
# 119                       question answering        33
# 81                        question answering        33
# 288                       question answering        33
# 310                       question answering        33
# 155                       question answering        33
# 93                        question answering        33
# 189                       question answering        33
# 362                       text summarization        34
# 430                       text summarization        34
# 330                       text summarization        34
# 232                       text summarization        34
# 208                       text summarization        34
# 182                       text summarization        34
# 62                        text summarization        34
# 451                       text summarization        34
# 405                       text summarization        34
# 377                       text summarization        34
# 143                       text summarization        34
# 85                        text summarization        34
# 292                       text summarization        34
# 240                       text summarization        34
# 314                       text summarization        34
# 159                       text summarization        34
# 361                         stance detection        35
# 429                         stance detection        35
# 329                         stance detection        35
# 231                         stance detection        35
# 207                         stance detection        35
# 181                         stance detection        35
# 61                          stance detection        35
# 404                         stance detection        35
# 275                         stance detection        35
# 376                         stance detection        35
# 253                         stance detection        35
# 142                         stance detection        35
# 122                         stance detection        35
# 84                          stance detection        35
# 291                         stance detection        35
# 313                         stance detection        35
# 386                         stance detection        35
# 158                         stance detection        35
# 95                          stance detection        35
# 357                         nlp applications        36
# 424                         nlp applications        36
# 227                         nlp applications        36
# 202                         nlp applications        36
# 176                         nlp applications        36
# 56                          nlp applications        36
# 447                         nlp applications        36
# 399                         nlp applications        36
# 270                         nlp applications        36
# 374                         nlp applications        36
# 250                         nlp applications        36
# 137                         nlp applications        36
# 286                         nlp applications        36
# 308                         nlp applications        36
# 343                         nlp applications        36
# 358                              predictions        37
# 425                              predictions        37
# 326                              predictions        37
# 228                              predictions        37
# 203                              predictions        37
# 177                              predictions        37
# 57                               predictions        37
# 448                              predictions        37
# 400                              predictions        37
# 271                              predictions        37
# 138                              predictions        37
# 118                              predictions        37
# 80                               predictions        37
# 35                               predictions        37
# 287                              predictions        37
# 309                              predictions        37
# 154                              predictions        37
# 344                              predictions        37
# 411                                 covid 19        38
# 214                                 covid 19        38
# 163                                 covid 19        38
# 42                                  covid 19        38
# 436                                 covid 19        38
# 259                                 covid 19        38
# 367                                 covid 19        38
# 109                                 covid 19        38
# 68                                  covid 19        38
# 298                                 covid 19        38
# 381                                 covid 19        38
# 147                                 covid 19        38
# 334                                 covid 19        38
# 349                           classification        40
# 409                           classification        40
# 318                           classification        40
# 212                           classification        40
# 192                           classification        40
# 162                           classification        40
# 98                            classification        40
# 40                            classification        40
# 434                           classification        40
# 388                           classification        40
# 257                           classification        40
# 365                           classification        40
# 242                           classification        40
# 125                           classification        40
# 108                           classification        40
# 66                            classification        40
# 27                            classification        40
# 278                           classification        40
# 296                           classification        40
# 379                           classification        40
# 146                           classification        40
# 333                           classification        40
# 88                            classification        40
# 185                           classification        40
# 416                   gender bias mitigation        41
# 320                   gender bias mitigation        41
# 219                   gender bias mitigation        41
# 168                   gender bias mitigation        41
# 47                    gender bias mitigation        41
# 439                   gender bias mitigation        41
# 391                   gender bias mitigation        41
# 263                   gender bias mitigation        41
# 72                    gender bias mitigation        41
# 236                   gender bias mitigation        41
# 302                   gender bias mitigation        41
# 431                    toxic spans detection        42
# 331                    toxic spans detection        42
# 209                    toxic spans detection        42
# 183                    toxic spans detection        42
# 105                    toxic spans detection        42
# 63                     toxic spans detection        42
# 452                    toxic spans detection        42
# 406                    toxic spans detection        42
# 254                    toxic spans detection        42
# 144                    toxic spans detection        42
# 86                     toxic spans detection        42
# 293                    toxic spans detection        42
# 315                    toxic spans detection        42
# 160                    toxic spans detection        42
# 346                    toxic spans detection        42
# 347                              Other tasks      9997
# 407                              Other tasks      9997
# 316                              Other tasks      9997
# 210                              Other tasks      9997
# 190                              Other tasks      9997
# 161                              Other tasks      9997
# 96                               Other tasks      9997
# 38                               Other tasks      9997
# 432                              Other tasks      9997
# 387                              Other tasks      9997
# 255                              Other tasks      9997
# 363                              Other tasks      9997
# 241                              Other tasks      9997
# 123                              Other tasks      9997
# 106                              Other tasks      9997
# 64                               Other tasks      9997
# 25                               Other tasks      9997
# 276                              Other tasks      9997
# 233                              Other tasks      9997
# 294                              Other tasks      9997
# 378                              Other tasks      9997
# 145                              Other tasks      9997
# 332                              Other tasks      9997
# 87                               Other tasks      9997
# 184                              Other tasks      9997
# 42                Good Health and Well-Being         2
# 120                        Quality Education         3
# 27                           Gender Equality         4
# 0                Affordable and Clean Energy         6
# 11           Decent Work and Economic Growth         7
# 66   Industry, Innovation and Infrastructure         8
# 142                     Reduced Inequalities         9
# 167       Sustainable Cities and Communities        10
# 164   Responsible Consumption and Production        11
# 2                             Climate Action        12
# 95    Peace, Justice and Strong Institutions        15
# 21                        sentiment analysis        17
# 6                              fact checking        18
# 2                  computational linguistics        19
# 0                                 annotation        20
# 16               natural language generation        21
# 14                       machine translation        22
# 12                    information extraction        23
# 11                                 inference        24
# 13                     information retrieval        25
# 10                                healthcare        26
# 15                  named entity recognition        27
# 5                           event extraction        28
# 4                            downstream task        29
# 9                                hate speech        30
# 7                        fake news detection        31
# 20                       relation extraction        32
# 19                        question answering        33
# 23                        text summarization        34
# 22                          stance detection        35
# 17                          nlp applications        36
# 18                               predictions        37
# 3                                   covid 19        38
# 1                             classification        40
# 8                     gender bias mitigation        41
# 24                     toxic spans detection        42
#
#                            target id_target  value      link_type  id_order
# 88             sentiment analysis        17    0.2     goal_tasks         0
# 87                  fact checking        18    0.2     goal_tasks         0
# 86      computational linguistics        19    0.2     goal_tasks         0
# 194            sentiment analysis        17    0.2     goal_tasks         1
# 191                 fact checking        18    0.2     goal_tasks         1
# 190     computational linguistics        19    0.2     goal_tasks         1
# 189                    annotation        20    0.5     goal_tasks         1
# 193   natural language generation        21    0.5     goal_tasks         1
# 192           machine translation        22    1.0     goal_tasks         1
# 63             sentiment analysis        17   22.8     goal_tasks         2
# 49                  fact checking        18    4.1     goal_tasks         2
# 45      computational linguistics        19    8.2     goal_tasks         2
# 43                     annotation        20   49.7     goal_tasks         2
# 58    natural language generation        21   17.3     goal_tasks         2
# 56            machine translation        22   40.8     goal_tasks         2
# 54         information extraction        23   25.5     goal_tasks         2
# 53                      inference        24   21.4     goal_tasks         2
# 55          information retrieval        25   31.6     goal_tasks         2
# 52                     healthcare        26   47.3     goal_tasks         2
# 57       named entity recognition        27  107.2     goal_tasks         2
# 48               event extraction        28   49.9     goal_tasks         2
# 47                downstream task        29   18.0     goal_tasks         2
# 51                    hate speech        30    4.0     goal_tasks         2
# 50            fake news detection        31    2.3     goal_tasks         2
# 62            relation extraction        32   56.1     goal_tasks         2
# 61             question answering        33   42.4     goal_tasks         2
# 65             text summarization        34   39.1     goal_tasks         2
# 64               stance detection        35    6.0     goal_tasks         2
# 59               nlp applications        36   16.5     goal_tasks         2
# 60                    predictions        37   16.8     goal_tasks         2
# 46                       covid 19        38   37.7     goal_tasks         2
# 44                 classification        40  116.2     goal_tasks         2
# 139            sentiment analysis        17    7.8     goal_tasks         3
# 125                 fact checking        18    2.0     goal_tasks         3
# 123     computational linguistics        19   29.2     goal_tasks         3
# 121                    annotation        20   35.5     goal_tasks         3
# 134   natural language generation        21   14.5     goal_tasks         3
# 132           machine translation        22  139.5     goal_tasks         3
# 130        information extraction        23    0.5     goal_tasks         3
# 129                     inference        24    3.5     goal_tasks         3
# 131         information retrieval        25   11.0     goal_tasks         3
# 128                    healthcare        26    2.3     goal_tasks         3
# 133      named entity recognition        27    8.0     goal_tasks         3
# 124               downstream task        29    4.5     goal_tasks         3
# 127                   hate speech        30   16.2     goal_tasks         3
# 126           fake news detection        31    1.0     goal_tasks         3
# 138           relation extraction        32    1.5     goal_tasks         3
# 137            question answering        33   12.0     goal_tasks         3
# 141            text summarization        34    9.5     goal_tasks         3
# 140              stance detection        35    1.0     goal_tasks         3
# 135              nlp applications        36    5.0     goal_tasks         3
# 136                   predictions        37    2.0     goal_tasks         3
# 122                classification        40   15.0     goal_tasks         3
# 40             sentiment analysis        17    2.0     goal_tasks         4
# 30      computational linguistics        19    2.0     goal_tasks         4
# 28                     annotation        20    3.5     goal_tasks         4
# 37    natural language generation        21    2.2     goal_tasks         4
# 36            machine translation        22   11.5     goal_tasks         4
# 35                      inference        24    0.2     goal_tasks         4
# 34                     healthcare        26    1.3     goal_tasks         4
# 31                downstream task        29    2.0     goal_tasks         4
# 33                    hate speech        30    2.0     goal_tasks         4
# 41             text summarization        34    0.2     goal_tasks         4
# 38               nlp applications        36    1.5     goal_tasks         4
# 39                    predictions        37    2.0     goal_tasks         4
# 29                 classification        40    4.5     goal_tasks         4
# 32         gender bias mitigation        41   28.0     goal_tasks         4
# 1                     predictions        37    1.0     goal_tasks         5
# 25             sentiment analysis        17    1.5     goal_tasks         7
# 16                  fact checking        18    1.0     goal_tasks         7
# 14      computational linguistics        19    2.0     goal_tasks         7
# 12                     annotation        20    0.3     goal_tasks         7
# 21    natural language generation        21    1.0     goal_tasks         7
# 19            machine translation        22   28.0     goal_tasks         7
# 17         information extraction        23    0.8     goal_tasks         7
# 18          information retrieval        25    1.0     goal_tasks         7
# 20       named entity recognition        27    2.3     goal_tasks         7
# 15                downstream task        29    1.3     goal_tasks         7
# 24             question answering        33    3.8     goal_tasks         7
# 26             text summarization        34    4.0     goal_tasks         7
# 22               nlp applications        36    1.3     goal_tasks         7
# 23                    predictions        37    1.0     goal_tasks         7
# 13                 classification        40    8.3     goal_tasks         7
# 79             sentiment analysis        17    1.0     goal_tasks         8
# 71                  fact checking        18    1.0     goal_tasks         8
# 69      computational linguistics        19    2.5     goal_tasks         8
# 67                     annotation        20    3.0     goal_tasks         8
# 74            machine translation        22   33.0     goal_tasks         8
# 72         information extraction        23    2.5     goal_tasks         8
# 73          information retrieval        25    2.5     goal_tasks         8
# 75       named entity recognition        27    1.0     goal_tasks         8
# 70               event extraction        28    0.5     goal_tasks         8
# 78             question answering        33    0.5     goal_tasks         8
# 80             text summarization        34    5.0     goal_tasks         8
# 76               nlp applications        36    2.0     goal_tasks         8
# 77                    predictions        37    0.5     goal_tasks         8
# 68                 classification        40    3.0     goal_tasks         8
# 160            sentiment analysis        17   16.0     goal_tasks         9
# 148                 fact checking        18    1.5     goal_tasks         9
# 145     computational linguistics        19    6.0     goal_tasks         9
# 143                    annotation        20    5.5     goal_tasks         9
# 155   natural language generation        21    9.2     goal_tasks         9
# 154           machine translation        22   17.0     goal_tasks         9
# 152                     inference        24    1.0     goal_tasks         9
# 153         information retrieval        25    0.7     goal_tasks         9
# 151                    healthcare        26    3.5     goal_tasks         9
# 147              event extraction        28    1.0     goal_tasks         9
# 146               downstream task        29   10.4     goal_tasks         9
# 150                   hate speech        30   16.8     goal_tasks         9
# 159           relation extraction        32    1.7     goal_tasks         9
# 158            question answering        33    1.5     goal_tasks         9
# 162            text summarization        34    4.2     goal_tasks         9
# 161              stance detection        35    4.5     goal_tasks         9
# 156              nlp applications        36   12.2     goal_tasks         9
# 157                   predictions        37    3.5     goal_tasks         9
# 144                classification        40   24.2     goal_tasks         9
# 149        gender bias mitigation        41    7.8     goal_tasks         9
# 163         toxic spans detection        42    4.2     goal_tasks         9
# 185            sentiment analysis        17   11.5     goal_tasks        10
# 173                 fact checking        18    4.5     goal_tasks        10
# 170     computational linguistics        19    8.8     goal_tasks        10
# 168                    annotation        20   11.5     goal_tasks        10
# 180   natural language generation        21    8.7     goal_tasks        10
# 178           machine translation        22   10.8     goal_tasks        10
# 176        information extraction        23    1.5     goal_tasks        10
# 175                     inference        24    2.5     goal_tasks        10
# 177         information retrieval        25    4.0     goal_tasks        10
# 179      named entity recognition        27    4.5     goal_tasks        10
# 172              event extraction        28    3.5     goal_tasks        10
# 171               downstream task        29    2.8     goal_tasks        10
# 174                   hate speech        30    4.0     goal_tasks        10
# 184           relation extraction        32    4.0     goal_tasks        10
# 183            question answering        33    5.8     goal_tasks        10
# 187            text summarization        34   10.7     goal_tasks        10
# 186              stance detection        35    5.5     goal_tasks        10
# 181              nlp applications        36    5.5     goal_tasks        10
# 182                   predictions        37    4.5     goal_tasks        10
# 169                classification        40   11.0     goal_tasks        10
# 188         toxic spans detection        42    7.5     goal_tasks        10
# 166                   predictions        37    1.0     goal_tasks        11
# 165                classification        40    1.0     goal_tasks        11
# 9              sentiment analysis        17    2.2     goal_tasks        12
# 6                   fact checking        18    1.2     goal_tasks        12
# 3                      annotation        20    1.2     goal_tasks        12
# 7        named entity recognition        27    2.0     goal_tasks        12
# 5                 downstream task        29    1.0     goal_tasks        12
# 8              question answering        33    0.2     goal_tasks        12
# 10             text summarization        34    0.2     goal_tasks        12
# 4                  classification        40    0.2     goal_tasks        12
# 81                  fact checking        18    1.0     goal_tasks        13
# 85    natural language generation        21    3.0     goal_tasks        14
# 83            machine translation        22    1.0     goal_tasks        14
# 84       named entity recognition        27    1.0     goal_tasks        14
# 82                downstream task        29    1.0     goal_tasks        14
# 116            sentiment analysis        17   25.8     goal_tasks        15
# 102                 fact checking        18   64.0     goal_tasks        15
# 98      computational linguistics        19   12.0     goal_tasks        15
# 96                     annotation        20   37.9     goal_tasks        15
# 111   natural language generation        21    6.3     goal_tasks        15
# 109           machine translation        22   19.7     goal_tasks        15
# 107        information extraction        23    6.8     goal_tasks        15
# 106                     inference        24    9.2     goal_tasks        15
# 108         information retrieval        25    9.5     goal_tasks        15
# 105                    healthcare        26    2.5     goal_tasks        15
# 110      named entity recognition        27   13.0     goal_tasks        15
# 101              event extraction        28    4.8     goal_tasks        15
# 100               downstream task        29    9.3     goal_tasks        15
# 104                   hate speech        30  161.8     goal_tasks        15
# 103           fake news detection        31   41.3     goal_tasks        15
# 115           relation extraction        32    4.8     goal_tasks        15
# 114            question answering        33   13.9     goal_tasks        15
# 118            text summarization        34   24.0     goal_tasks        15
# 117              stance detection        35   51.5     goal_tasks        15
# 112              nlp applications        36   16.8     goal_tasks        15
# 113                   predictions        37   14.7     goal_tasks        15
# 99                       covid 19        38    2.0     goal_tasks        15
# 97                 classification        40   77.8     goal_tasks        15
# 119         toxic spans detection        42   27.3     goal_tasks        15
# 93             sentiment analysis        17    0.5     goal_tasks        16
# 89                     annotation        20    0.5     goal_tasks        16
# 91            machine translation        22    1.8     goal_tasks        16
# 90          information retrieval        25    0.5     goal_tasks        16
# 94               stance detection        35    0.2     goal_tasks        16
# 92               nlp applications        36    0.2     goal_tasks        16
# 360           supervised learning        43    0.8  tasks_methods       999
# 428                  transformers        45    0.5  tasks_methods       999
# 328     recurrent neural networks        46    1.5  tasks_methods       999
# 230      machine learning methods        47    5.5  tasks_methods       999
# 206                          lstm        48    0.3  tasks_methods       999
# 180               language models        49    1.2  tasks_methods       999
# 60                           bert        51    6.0  tasks_methods       999
# 450               word embeddings        52    0.5  tasks_methods       999
# 403             transfer learning        53    0.7  tasks_methods       999
# 274                 neural models        54    0.5  tasks_methods       999
# 252           multi task learning        56    2.1  tasks_methods       999
# 141           deep neural network        57    3.6  tasks_methods       999
# 121  convolutional neural network        58    1.0  tasks_methods       999
# 83                    classifiers        59    3.8  tasks_methods       999
# 37                    annotations        60    1.3  tasks_methods       999
# 290                neural network        61    1.7  tasks_methods       999
# 312                    nlp models        63    2.5  tasks_methods       999
# 385                  topic models        64    1.0  tasks_methods       999
# 157              ensemble methods        65    0.3  tasks_methods       999
# 345                       roberta        66    0.5  tasks_methods       999
# 94           computational models        67    0.5  tasks_methods       999
# 352           supervised learning        43    0.3  tasks_methods       999
# 414                  transformers        45    3.4  tasks_methods       999
# 217      machine learning methods        47    3.6  tasks_methods       999
# 195                          lstm        48    0.5  tasks_methods       999
# 166               language models        49    0.8  tasks_methods       999
# 45                           bert        51    5.2  tasks_methods       999
# 262                 neural models        54    1.2  tasks_methods       999
# 245           multi task learning        56    3.5  tasks_methods       999
# 128           deep neural network        57    1.7  tasks_methods       999
# 112  convolutional neural network        58    1.0  tasks_methods       999
# 70                    classifiers        59    2.7  tasks_methods       999
# 280                neural network        61    1.0  tasks_methods       999
# 235    machine translation system        62    0.5  tasks_methods       999
# 300                    nlp models        63    1.0  tasks_methods       999
# 149              ensemble methods        65    1.5  tasks_methods       999
# 337                       roberta        66    1.0  tasks_methods       999
# 89           computational models        67    0.5  tasks_methods       999
# 350           supervised learning        43    0.3  tasks_methods       999
# 410                  transformers        45    1.2  tasks_methods       999
# 213      machine learning methods        47    1.2  tasks_methods       999
# 193                          lstm        48    1.0  tasks_methods       999
# 41                           bert        51    0.2  tasks_methods       999
# 435               word embeddings        52    1.5  tasks_methods       999
# 258                 neural models        54    1.0  tasks_methods       999
# 366        support vector machine        55    0.2  tasks_methods       999
# 126           deep neural network        57    1.0  tasks_methods       999
# 67                    classifiers        59    1.0  tasks_methods       999
# 234    machine translation system        62    0.5  tasks_methods       999
# 297                    nlp models        63    3.0  tasks_methods       999
# 380                  topic models        64    2.0  tasks_methods       999
# 186           language technology        68    2.0  tasks_methods       999
# 348           supervised learning        43    1.0  tasks_methods       999
# 408                  transformers        45    1.8  tasks_methods       999
# 317     recurrent neural networks        46    0.5  tasks_methods       999
# 211      machine learning methods        47    5.1  tasks_methods       999
# 191                          lstm        48    1.2  tasks_methods       999
# ...
# 178               language models        49    3.9  tasks_methods       999
# 58                           bert        51    3.8  tasks_methods       999
# 401             transfer learning        53    0.7  tasks_methods       999
# 272                 neural models        54    0.8  tasks_methods       999
# 139           deep neural network        57    2.5  tasks_methods       999
# 119  convolutional neural network        58    1.3  tasks_methods       999
# 81                    classifiers        59    2.0  tasks_methods       999
# 288                neural network        61    2.5  tasks_methods       999
# 310                    nlp models        63    0.8  tasks_methods       999
# 155              ensemble methods        65    1.0  tasks_methods       999
# 93           computational models        67    0.5  tasks_methods       999
# 189           language technology        68    1.0  tasks_methods       999
# 362           supervised learning        43    1.0  tasks_methods       999
# 430                  transformers        45    1.0  tasks_methods       999
# 330     recurrent neural networks        46    0.7  tasks_methods       999
# 232      machine learning methods        47    1.0  tasks_methods       999
# 208                          lstm        48    0.2  tasks_methods       999
# 182               language models        49    1.8  tasks_methods       999
# 62                           bert        51    3.2  tasks_methods       999
# 451               word embeddings        52    1.0  tasks_methods       999
# 405             transfer learning        53    1.0  tasks_methods       999
# 377        support vector machine        55    1.0  tasks_methods       999
# 143           deep neural network        57    2.2  tasks_methods       999
# 85                    classifiers        59    1.0  tasks_methods       999
# 292                neural network        61    1.0  tasks_methods       999
# 240    machine translation system        62    1.5  tasks_methods       999
# 314                    nlp models        63    1.5  tasks_methods       999
# 159              ensemble methods        65    1.0  tasks_methods       999
# 361           supervised learning        43    0.2  tasks_methods       999
# 429                  transformers        45    1.3  tasks_methods       999
# 329     recurrent neural networks        46    0.5  tasks_methods       999
# 231      machine learning methods        47    2.3  tasks_methods       999
# 207                          lstm        48    1.0  tasks_methods       999
# 181               language models        49    1.7  tasks_methods       999
# 61                           bert        51    0.8  tasks_methods       999
# 404             transfer learning        53    1.5  tasks_methods       999
# 275                 neural models        54    2.8  tasks_methods       999
# 376        support vector machine        55    1.4  tasks_methods       999
# 253           multi task learning        56    2.8  tasks_methods       999
# 142           deep neural network        57    2.2  tasks_methods       999
# 122  convolutional neural network        58    2.2  tasks_methods       999
# 84                    classifiers        59    2.2  tasks_methods       999
# 291                neural network        61    2.3  tasks_methods       999
# 313                    nlp models        63    1.0  tasks_methods       999
# 386                  topic models        64    0.5  tasks_methods       999
# 158              ensemble methods        65    0.8  tasks_methods       999
# 95           computational models        67    1.0  tasks_methods       999
# 357           supervised learning        43    0.5  tasks_methods       999
# 424                  transformers        45    1.0  tasks_methods       999
# 227      machine learning methods        47    3.7  tasks_methods       999
# 202                          lstm        48    1.5  tasks_methods       999
# 176               language models        49    4.5  tasks_methods       999
# 56                           bert        51    9.6  tasks_methods       999
# 447               word embeddings        52    3.2  tasks_methods       999
# 399             transfer learning        53    0.4  tasks_methods       999
# 270                 neural models        54    0.2  tasks_methods       999
# 374        support vector machine        55    1.4  tasks_methods       999
# 250           multi task learning        56    0.4  tasks_methods       999
# 137           deep neural network        57    3.2  tasks_methods       999
# 286                neural network        61    0.5  tasks_methods       999
# 308                    nlp models        63    1.3  tasks_methods       999
# 343                       roberta        66    0.1  tasks_methods       999
# 358           supervised learning        43    1.5  tasks_methods       999
# 425                  transformers        45    3.1  tasks_methods       999
# 326     recurrent neural networks        46    0.5  tasks_methods       999
# 228      machine learning methods        47    3.5  tasks_methods       999
# 203                          lstm        48    1.0  tasks_methods       999
# 177               language models        49    1.5  tasks_methods       999
# 57                           bert        51    3.0  tasks_methods       999
# 448               word embeddings        52    1.5  tasks_methods       999
# 400             transfer learning        53    0.8  tasks_methods       999
# 271                 neural models        54    0.2  tasks_methods       999
# 138           deep neural network        57    1.8  tasks_methods       999
# 118  convolutional neural network        58    1.2  tasks_methods       999
# 80                    classifiers        59    0.7  tasks_methods       999
# 35                    annotations        60    0.5  tasks_methods       999
# 287                neural network        61    0.5  tasks_methods       999
# 309                    nlp models        63    0.2  tasks_methods       999
# 154              ensemble methods        65    1.5  tasks_methods       999
# 344                       roberta        66    0.2  tasks_methods       999
# 411                  transformers        45    3.2  tasks_methods       999
# 214      machine learning methods        47    1.4  tasks_methods       999
# 163               language models        49    1.0  tasks_methods       999
# 42                           bert        51    4.4  tasks_methods       999
# 436               word embeddings        52    1.0  tasks_methods       999
# 259                 neural models        54    1.0  tasks_methods       999
# 367        support vector machine        55    0.4  tasks_methods       999
# 109  convolutional neural network        58    0.2  tasks_methods       999
# 68                    classifiers        59    1.7  tasks_methods       999
# 298                    nlp models        63    0.5  tasks_methods       999
# 381                  topic models        64    1.0  tasks_methods       999
# 147              ensemble methods        65    1.5  tasks_methods       999
# 334                       roberta        66    1.0  tasks_methods       999
# 349           supervised learning        43    4.8  tasks_methods       999
# 409                  transformers        45    7.3  tasks_methods       999
# 318     recurrent neural networks        46    3.3  tasks_methods       999
# 212      machine learning methods        47   16.2  tasks_methods       999
# 192                          lstm        48    3.0  tasks_methods       999
# 162               language models        49    9.6  tasks_methods       999
# 98       conditional random field        50    3.1  tasks_methods       999
# 40                           bert        51   16.3  tasks_methods       999
# 434               word embeddings        52    5.6  tasks_methods       999
# 388             transfer learning        53    2.2  tasks_methods       999
# 257                 neural models        54    0.6  tasks_methods       999
# 365        support vector machine        55   11.8  tasks_methods       999
# 242           multi task learning        56    0.3  tasks_methods       999
# 125           deep neural network        57    8.5  tasks_methods       999
# 108  convolutional neural network        58    6.2  tasks_methods       999
# 66                    classifiers        59   26.3  tasks_methods       999
# 27                    annotations        60    0.6  tasks_methods       999
# 278                neural network        61    3.5  tasks_methods       999
# 296                    nlp models        63    4.7  tasks_methods       999
# 379                  topic models        64    1.5  tasks_methods       999
# 146              ensemble methods        65    2.3  tasks_methods       999
# 333                       roberta        66    5.0  tasks_methods       999
# 88           computational models        67    1.5  tasks_methods       999
# 185           language technology        68    0.5  tasks_methods       999
# 416                  transformers        45    0.5  tasks_methods       999
# 320     recurrent neural networks        46    1.0  tasks_methods       999
# 219      machine learning methods        47    2.2  tasks_methods       999
# 168               language models        49    1.5  tasks_methods       999
# 47                           bert        51    1.7  tasks_methods       999
# 439               word embeddings        52    5.7  tasks_methods       999
# 391             transfer learning        53    0.9  tasks_methods       999
# 263                 neural models        54    0.2  tasks_methods       999
# 72                    classifiers        59    0.3  tasks_methods       999
# 236    machine translation system        62    0.9  tasks_methods       999
# 302                    nlp models        63    0.8  tasks_methods       999
# 431                  transformers        45    2.9  tasks_methods       999
# 331     recurrent neural networks        46    1.2  tasks_methods       999
# 209                          lstm        48    2.1  tasks_methods       999
# 183               language models        49    3.1  tasks_methods       999
# 105      conditional random field        50    2.0  tasks_methods       999
# 63                           bert        51    3.6  tasks_methods       999
# 452               word embeddings        52    0.1  tasks_methods       999
# 406             transfer learning        53    0.5  tasks_methods       999
# 254           multi task learning        56    0.5  tasks_methods       999
# 144           deep neural network        57    0.5  tasks_methods       999
# 86                    classifiers        59    2.0  tasks_methods       999
# 293                neural network        61    0.2  tasks_methods       999
# 315                    nlp models        63    2.0  tasks_methods       999
# 160              ensemble methods        65    1.5  tasks_methods       999
# 346                       roberta        66    3.6  tasks_methods       999
# 347           supervised learning        43   26.5  tasks_methods       999
# 407                  transformers        45   51.4  tasks_methods       999
# 316     recurrent neural networks        46   19.2  tasks_methods       999
# 210      machine learning methods        47  156.9  tasks_methods       999
# 190                          lstm        48   36.8  tasks_methods       999
# 161               language models        49   93.0  tasks_methods       999
# 96       conditional random field        50   39.4  tasks_methods       999
# 38                           bert        51  124.2  tasks_methods       999
# 432               word embeddings        52   66.3  tasks_methods       999
# 387             transfer learning        53   16.7  tasks_methods       999
# 255                 neural models        54   31.2  tasks_methods       999
# 363        support vector machine        55   53.5  tasks_methods       999
# 241           multi task learning        56   18.9  tasks_methods       999
# 123           deep neural network        57   76.8  tasks_methods       999
# 106  convolutional neural network        58   30.2  tasks_methods       999
# 64                    classifiers        59  122.3  tasks_methods       999
# 25                    annotations        60   40.8  tasks_methods       999
# 276                neural network        61   40.8  tasks_methods       999
# 233    machine translation system        62   35.7  tasks_methods       999
# 294                    nlp models        63   67.2  tasks_methods       999
# 378                  topic models        64   27.3  tasks_methods       999
# 145              ensemble methods        65   24.8  tasks_methods       999
# 332                       roberta        66   16.4  tasks_methods       999
# 87           computational models        67   24.2  tasks_methods       999
# 184           language technology        68   39.3  tasks_methods       999
# 42                    Other tasks      9997  484.5     goal_tasks      9999
# 120                   Other tasks      9997  171.5     goal_tasks      9999
# 27                    Other tasks      9997   30.5     goal_tasks      9999
# 0                     Other tasks      9997    3.0     goal_tasks      9999
# 11                    Other tasks      9997   24.5     goal_tasks      9999
# 66                    Other tasks      9997   18.5     goal_tasks      9999
# 142                   Other tasks      9997   97.0     goal_tasks      9999
# 167                   Other tasks      9997   79.0     goal_tasks      9999
# 164                   Other tasks      9997    1.0     goal_tasks      9999
# 2                     Other tasks      9997    8.0     goal_tasks      9999
# 95                    Other tasks      9997  362.5     goal_tasks      9999
# 21                  Other methods      9998   55.6  tasks_methods      9999
# 6                   Other methods      9998   51.2  tasks_methods      9999
# 2                   Other methods      9998   54.9  tasks_methods      9999
# 0                   Other methods      9998  102.8  tasks_methods      9999
# 16                  Other methods      9998   48.5  tasks_methods      9999
# 14                  Other methods      9998  224.5  tasks_methods      9999
# 12                  Other methods      9998   26.7  tasks_methods      9999
# 11                  Other methods      9998   23.5  tasks_methods      9999
# 13                  Other methods      9998   46.6  tasks_methods      9999
# 10                  Other methods      9998   30.2  tasks_methods      9999
# 15                  Other methods      9998   65.7  tasks_methods      9999
# 5                   Other methods      9998   42.0  tasks_methods      9999
# 4                   Other methods      9998   26.9  tasks_methods      9999
# 9                   Other methods      9998   63.0  tasks_methods      9999
# 7                   Other methods      9998   27.6  tasks_methods      9999
# 20                  Other methods      9998   38.2  tasks_methods      9999
# 19                  Other methods      9998   54.3  tasks_methods      9999
# 23                  Other methods      9998   77.0  tasks_methods      9999
# 22                  Other methods      9998   40.2  tasks_methods      9999
# 17                  Other methods      9998   29.6  tasks_methods      9999
# 18                  Other methods      9998   23.7  tasks_methods      9999
# 3                   Other methods      9998   21.5  tasks_methods      9999
# 1                   Other methods      9998  116.5  tasks_methods      9999
# 8                   Other methods      9998   20.2  tasks_methods      9999
# 24                  Other methods      9998   13.2  tasks_methods      9999
#
# [648 rows x 7 columns]

# %%
sources=df_sankey.loc[:,['source','id_order']].rename(columns={'source':'name'})
targets=df_sankey.loc[:,['target','id_order']].rename(columns={'target':'name'})

# %%
order_df=pd.concat([sources,targets]).drop_duplicates(subset=['name'],keep='first').sort_values(['id_order','name'])

# %%
order_df=order_df.assign(id_order=np.where(order_df.name.isin(['No organization','Other methods','Other tasks']),
                                             9999,order_df.id_order))

# %%
order_df=order_df.sort_values(['id_order','name'])

# %%
order_df=order_df.reset_index(drop=True).reset_index().rename(columns={'index':'order'})

# %%
order_df=order_df.assign(node_type=np.where(order_df.name.isin(goals_list.name.unique()),"Goal",
                                np.where(order_df.name.isin(tasks_list.name.unique()),"Task","Method")))

# %%
order_df
# Out:
#     order                                     name  id_order node_type
# 0       0                               No Poverty         0      Goal
# 1       1                              Zero Hunger         1      Goal
# 2       2               Good Health and Well-Being         2      Goal
# 3       3                        Quality Education         3      Goal
# 4       4                          Gender Equality         4      Goal
# 5       5               Clean Water and Sanitation         5      Goal
# 6       6          Decent Work and Economic Growth         7      Goal
# 7       7  Industry, Innovation and Infrastructure         8      Goal
# 8       8                     Reduced Inequalities         9      Goal
# 9       9       Sustainable Cities and Communities        10      Goal
# 10     10   Responsible Consumption and Production        11      Goal
# 11     11                           Climate Action        12      Goal
# 12     12                         Life Below Water        13      Goal
# 13     13                             Life on Land        14      Goal
# 14     14   Peace, Justice and Strong Institutions        15      Goal
# 15     15                Partnership for the Goals        16      Goal
# 16     16                               annotation       999      Task
# 17     17                              annotations       999    Method
# 18     18                                     bert       999    Method
# 19     19                           classification       999      Task
# 20     20                              classifiers       999    Method
# 21     21                computational linguistics       999      Task
# 22     22                     computational models       999    Method
# 23     23                 conditional random field       999    Method
# 24     24             convolutional neural network       999    Method
# 25     25                                 covid 19       999      Task
# 26     26                      deep neural network       999    Method
# 27     27                          downstream task       999      Task
# 28     28                         ensemble methods       999    Method
# 29     29                         event extraction       999      Task
# 30     30                            fact checking       999      Task
# 31     31                      fake news detection       999      Task
# 32     32                   gender bias mitigation       999      Task
# 33     33                              hate speech       999      Task
# 34     34                               healthcare       999      Task
# 35     35                                inference       999      Task
# 36     36                   information extraction       999      Task
# 37     37                    information retrieval       999      Task
# 38     38                          language models       999    Method
# 39     39                      language technology       999    Method
# 40     40                                     lstm       999    Method
# 41     41                 machine learning methods       999    Method
# 42     42                      machine translation       999      Task
# 43     43               machine translation system       999    Method
# 44     44                      multi task learning       999    Method
# 45     45                 named entity recognition       999      Task
# 46     46              natural language generation       999      Task
# 47     47                            neural models       999    Method
# 48     48                           neural network       999    Method
# 49     49                         nlp applications       999      Task
# 50     50                               nlp models       999    Method
# 51     51                              predictions       999      Task
# 52     52                       question answering       999      Task
# 53     53                recurrent neural networks       999    Method
# 54     54                      relation extraction       999      Task
# 55     55                                  roberta       999    Method
# 56     56                       sentiment analysis       999      Task
# 57     57                         stance detection       999      Task
# 58     58                      supervised learning       999    Method
# 59     59                   support vector machine       999    Method
# 60     60                       text summarization       999      Task
# 61     61                             topic models       999    Method
# 62     62                    toxic spans detection       999      Task
# 63     63                        transfer learning       999    Method
# 64     64                             transformers       999    Method
# 65     65                          word embeddings       999    Method
# 66     66              Affordable and Clean Energy      9999      Goal
# 67     67                            Other methods      9999    Method
# 68     68                              Other tasks      9999      Task

# %%
order_dict = dict(zip(order_df.name, order_df.order))

# %%
with open('order_sankey.json', 'w') as fp:
    json.dump(order_dict, fp)

# %%
order_df.loc[:,['name','node_type']].to_json("names.json",orient="records")

# %% [markdown]
# ## papers

# %%
positives=pd.read_csv(outputs_path+"sg_ie/positives_ready.csv")

# %%
positives.shape
# Out:
# (8133, 13)

# %%
positives=positives.loc[:,['ID','title_clean','abstract_clean']]

# %%
papers_dataset=df_all_goals.loc[:,['ID','title_clean','abstract_clean']]

# %%
positives=positives.loc[~positives.ID.isin(papers_dataset.ID.unique())]

# %%
positives=pd.concat([positives,papers_dataset])

# %%
df_labels_task_save=df_labels_task.loc[:,['ID', 'methods', 'tasks', 'Goal',
      'center_task','center_method']]

# %%
df_labels_task_save.shape
# Out:
# (39934, 6)

# %%
methods_grouped=df_labels_task_save.loc[:,['ID','methods','center_method']].drop_duplicates().groupby(['ID']).agg({'methods':lambda x: list(x),'center_method':lambda x: list(x)}).reset_index()

tasks_grouped=df_labels_task_save.loc[:,['ID','tasks','center_task']].drop_duplicates().groupby(['ID']).agg({'tasks':lambda x: list(x),'center_task':lambda x: list(x)}).reset_index()

goal_grouped=df_labels_task_save.loc[:,['ID','Goal']].drop_duplicates().groupby(['ID']).agg({'Goal':lambda x: list(x)}).reset_index()

df_labels_task_save=methods_grouped.merge(tasks_grouped,on=['ID'],how='left').merge(goal_grouped,on=['ID'],how='left').merge(positives,on='ID',how='left')

df_labels_task_save=df_labels_task_save.assign(title_clean=df_labels_task_save.title_clean.replace("-"," ",regex=True).replace("  "," ",regex=True))
df_labels_task_save=df_labels_task_save.assign(abstract_clean=df_labels_task_save.abstract_clean.replace("-"," ",regex=True).replace("  "," ",regex=True))

# %%
df_labels_task_save.to_json("papers_features.json",orient="records")

# %%
df_labels_task_save.loc[df_labels_task_save.ID=='amin-etal-2020-data']
# Out:
#                       ID                                            methods  \
# 281  amin-etal-2020-data  [data encoding scheme, entity enriched relatio...
#
#        center_method                  tasks            center_task  \
# 281  [nan, nan, nan]  [relation extraction]  [relation extraction]
#
#                              Goal  \
# 281  [Good Health and Well-Being]
#
#                                            title_clean  \
# 281  A Data driven Approach for Noise Reduction in ...
#
#                                         abstract_clean
# 281  Fact triples are a common form of structured k...

# %%
df_labels_task_save.ID.value_counts()
# Out:
# 039b1c1210c437f3b3ce6e0275ee2137bf5b951c       1
# perez-almendros-etal-2020-dont                 1
# perello-etal-2019-ua                           1
# perek-2014-vector                              1
